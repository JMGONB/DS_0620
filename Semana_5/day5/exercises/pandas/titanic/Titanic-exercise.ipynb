# %% [markdown]
#    #                                                  Titanic Exercise
#    #### Practise Pandas

# %% [markdown]
# ![titanic](https://userscontent2.emaze.com/images/a5f68f37-6349-4065-a1fc-921cbe7401b2/958230111417e36d6b3c67ffd7bc3494.jpeg)

# %% [markdown]
# First of all, import the needed libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# you will have to import at least two other libraries along the exercise

# %% [markdown]
# 1. Read in filename and call the variable `titanic`
#     - Explore the `titanic` dataset using `info`, `dtypes` & `describe`

# %%
filename = "titanic.csv"

# %%
titanic = pd.read_csv(filename, sep=",")
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 107.4+ KB

# %%
titanic.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
titanic.shape
# Out:
# (1309, 14)

# %% [markdown]
# 2. Create a separate dataframe with the columns `['name', 'sex', 'age']`, call it `people`
#
# It can be done two ways, do it both!

# %%
people=titanic[['name', 'sex', 'age']]
people
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %% [markdown]
# 3. Print the output of `people` showing the first three rows and the last four rows, using `append`,`tail` and `head`

# %%
titanic1=titanic.head(3)
titanic1
# Out:
#    pclass  survived                            name     sex    age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female  29.00      0
# 1       1         1  Allison, Master. Hudson Trevor    male   0.92      1
# 2       1         0    Allison, Miss. Helen Loraine  female   2.00      1
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0      0   24160  211.3375       B5        S    2   NaN
# 1      2  113781  151.5500  C22 C26        S   11   NaN
# 2      2  113781  151.5500  C22 C26        S  NaN   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON

# %%
titanic2=titanic.tail(4)
titanic2
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
titanic1.append(titanic2, ignore_index=False)
# Out:
#       pclass  survived                            name     sex    age  sibsp  \
# 0          1         1   Allen, Miss. Elisabeth Walton  female  29.00      0
# 1          1         1  Allison, Master. Hudson Trevor    male   0.92      1
# 2          1         0    Allison, Miss. Helen Loraine  female   2.00      1
# 1305       3         0           Zabour, Miss. Thamine  female    NaN      1
# 1306       3         0       Zakarian, Mr. Mapriededer    male  26.50      0
# 1307       3         0             Zakarian, Mr. Ortin    male  27.00      0
# 1308       3         0              Zimmerman, Mr. Leo    male  29.00      0
#
#       parch  ticket      fare    cabin embarked boat   body  \
# 0         0   24160  211.3375       B5        S    2    NaN
# 1         2  113781  151.5500  C22 C26        S   11    NaN
# 2         2  113781  151.5500  C22 C26        S  NaN    NaN
# 1305      0    2665   14.4542      NaN        C  NaN    NaN
# ...

# %% [markdown]
# 4. Slice the row from 3 to 9, call it `s_titanic`

# %%
s_titanic=titanic.iloc[3:10,:]
s_titanic
# Out:
#    pclass  survived                                             name     sex  \
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#     age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 3  30.0      1      2    113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0      1      2    113781  151.5500  C22 C26        S  NaN    NaN
# 5  48.0      0      0     19952   26.5500      E12        S    3    NaN
# ...

# %% [markdown]
# 5. Slice the row from 40 to 63 in reverse order, call it `s_titanic_rev`

# %%
s_titanic_rev=titanic.iloc[::-1,:]

# %%
s_titanic_rev.iloc[1246:1269,:]
# Out:
#     pclass  survived                                               name  \
# 62       1         0                        Chaffee, Mr. Herbert Fuller
# 61       1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 60       1         0                      Cavendish, Mr. Tyrell William
# 59       1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# 58       1         0                             Case, Mr. Howard Brown
# 57       1         1          Carter, Mrs. William Ernest (Lucile Polk)
# 56       1         1                         Carter, Mr. William Ernest
# 55       1         1                          Carter, Miss. Lucile Polk
# 54       1         1                Carter, Master. William Thornton II
# 53       1         0                             Carrau, Mr. Jose Pedro
# 52       1         0                            Carrau, Mr. Francisco M
# 51       1         0                           Carlsson, Mr. Frans Olof
# ...

# %% [markdown]
# 6. Slice the columns from the starting column to `'parch'`, call it `left_columns`

# %%
left_columns=titanic.loc[:,"pclass":"parch"]
left_columns
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch
# 0     female  29.00      0      0
# ...

# %% [markdown]
# 7. Slice the columns from `'name'` to `'age'`, call it `middle_columns`

# %%
a=titanic.drop(["name","sex","age"], axis=1)
a
# Out:
#       pclass  survived  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0          1         1      0      0   24160  211.3375       B5        S    2
# 1          1         1      1      2  113781  151.5500  C22 C26        S   11
# 2          1         0      1      2  113781  151.5500  C22 C26        S  NaN
# 3          1         0      1      2  113781  151.5500  C22 C26        S  NaN
# 4          1         0      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...       ...    ...    ...     ...       ...      ...      ...  ...
# 1304       3         0      1      0    2665   14.4542      NaN        C  NaN
# 1305       3         0      1      0    2665   14.4542      NaN        C  NaN
# 1306       3         0      0      0    2656    7.2250      NaN        C  NaN
# 1307       3         0      0      0    2670    7.2250      NaN        C  NaN
# 1308       3         0      0      0  315082    7.8750      NaN        S  NaN
#
# ...

# %% [markdown]
# 8. Slice the columns from `'ticket'` to the end, call it `right_columns`

# %%
right_columns=titanic.iloc[:,7::]
right_columns
# Out:
#       ticket      fare    cabin embarked boat   body  \
# 0      24160  211.3375       B5        S    2    NaN
# 1     113781  151.5500  C22 C26        S   11    NaN
# 2     113781  151.5500  C22 C26        S  NaN    NaN
# 3     113781  151.5500  C22 C26        S  NaN  135.0
# 4     113781  151.5500  C22 C26        S  NaN    NaN
# ...      ...       ...      ...      ...  ...    ...
# 1304    2665   14.4542      NaN        C  NaN  328.0
# 1305    2665   14.4542      NaN        C  NaN    NaN
# 1306    2656    7.2250      NaN        C  NaN  304.0
# 1307    2670    7.2250      NaN        C  NaN    NaN
# 1308  315082    7.8750      NaN        S  NaN    NaN
#
#                             home.dest
# 0                        St Louis, MO
# 1     Montreal, PQ / Chesterville, ON
# 2     Montreal, PQ / Chesterville, ON
# 3     Montreal, PQ / Chesterville, ON
# 4     Montreal, PQ / Chesterville, ON
# ...                               ...
# 1304                              NaN
# ...

# %% [markdown]
# 9. What is the name of the oldest person who died in the Titanic? Was he or she travelling alone or had any family travelling with them?

# %%
max(titanic.age)
# Out:
# 80.0

# %%
titanic.age[titanic.age == max (titanic.age)]
# Out:
# 14    80.0
# Name: age, dtype: float64

# %% [markdown]
# In order to give an answer to the second question you should find out which columns give you that info. Usually part of your job as a Data Scientist will be get to know the dataset which you are working with. In this case the columns which give you that info are the following:
#         - 'sibsp' Number of Siblings/Spouses Aboard
#         - 'parch' Number of Parents/Children Aboard

# %%
titanic.iloc[14,:].loc[["sibsp","parch"]]
# Out:
# sibsp    0
# parch    0
# Name: 14, dtype: object

# %% [markdown]
# 10. Create the list of 5 random numbers of rows from 0 to the lenght of the dataframe, call it `rows`
#
# ex. `rows = [3,7,99,52,48]` use `random` library

# %%
titanic.sample(5,random_state=18326)
# Out:
#       pclass  survived                               name   sex   age  sibsp  \
# 691        3         0    Brocklebank, Mr. William Alfred  male  35.0      0
# 1274       3         0          Vander Planke, Mr. Julius  male  31.0      3
# 189        1         0             Long, Mr. Milton Clyde  male  29.0      0
# 45         1         0  Butt, Major. Archibald Willingham  male  45.0      0
# 40         1         0          Brewe, Dr. Arthur Jackson  male   NaN      0
#
#       parch  ticket   fare cabin embarked boat   body  \
# 691       0  364512   8.05   NaN        S  NaN    NaN
# 1274      0  345763  18.00   NaN        S  NaN    NaN
# 189       0  113501  30.00    D6        S  NaN  126.0
# 45        0  113050  26.55   B38        S  NaN    NaN
# 40        0  112379  39.60   NaN        C  NaN    NaN
#
#                             home.dest
# 691   Broomfield, Chelmsford, England
# 1274                              NaN
# 189                   Springfield, MA
# ...

# %% [markdown]
# 11. Create the list of three column labels, call it `cols`

# %%
cols=titanic.sample(3,random_state=18326,axis=1)
cols
# Out:
#                                                  name   body embarked
# 0                       Allen, Miss. Elisabeth Walton    NaN        S
# 1                      Allison, Master. Hudson Trevor    NaN        S
# 2                        Allison, Miss. Helen Loraine    NaN        S
# 3                Allison, Mr. Hudson Joshua Creighton  135.0        S
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    NaN        S
# ...                                               ...    ...      ...
# 1304                             Zabour, Miss. Hileni  328.0        C
# 1305                            Zabour, Miss. Thamine    NaN        C
# 1306                        Zakarian, Mr. Mapriededer  304.0        C
# 1307                              Zakarian, Mr. Ortin    NaN        C
# 1308                               Zimmerman, Mr. Leo    NaN        S
#
# [1309 rows x 3 columns]

# %% [markdown]
# 12. Use both lists `rows` and `cols` to create a new dataframe

# %%
new_data=pd.DataFrame(cols)
new_data
# Out:
#                                                  name   body embarked
# 0                       Allen, Miss. Elisabeth Walton    NaN        S
# 1                      Allison, Master. Hudson Trevor    NaN        S
# 2                        Allison, Miss. Helen Loraine    NaN        S
# 3                Allison, Mr. Hudson Joshua Creighton  135.0        S
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    NaN        S
# ...                                               ...    ...      ...
# 1304                             Zabour, Miss. Hileni  328.0        C
# 1305                            Zabour, Miss. Thamine    NaN        C
# 1306                        Zakarian, Mr. Mapriededer  304.0        C
# 1307                              Zakarian, Mr. Ortin    NaN        C
# 1308                               Zimmerman, Mr. Leo    NaN        S
#
# [1309 rows x 3 columns]

# %% [markdown]
# 13. Create a boolean array with the condition of being a woman or a man, using the `sex` column, where **female** is True. Call it `array_fe`

# %%
array_fe=titanic["sex"]=="female"
array_fe
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 1304     True
# 1305     True
# 1306    False
# 1307    False
# 1308    False
# Name: sex, Length: 1309, dtype: bool

# %% [markdown]
# Bonus: Rename the column `"sex"` to `"gender"`

# %%
titanic.rename(columns={"sex":"gender"})
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#       gender    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# 14. Filter the `titanic` dataframe with the boolean array, call it `woman_titanic`

# %%
woman_titanic=titanic[titanic["sex"]=="female"]
woman_titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# 15. How many woman were younger than 18? Call the variable `minor_wo`

# %%
minor_wo=titanic[titanic.age <18]
minor_wo
# Out:
#       pclass  survived                                     name     sex  \
# 1          1         1           Allison, Master. Hudson Trevor    male
# 2          1         0             Allison, Miss. Helen Loraine  female
# 53         1         0                   Carrau, Mr. Jose Pedro    male
# 54         1         1      Carter, Master. William Thornton II    male
# 55         1         1                Carter, Miss. Lucile Polk  female
# ...      ...       ...                                      ...     ...
# 1265       3         0                Van Impe, Miss. Catharina  female
# 1275       3         0          Vander Planke, Mr. Leo Edmondus    male
# 1279       3         0     Vestrom, Miss. Hulda Amanda Adolfina  female
# 1300       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female
# 1304       3         0                     Zabour, Miss. Hileni  female
#
#         age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# ...

# %% [markdown]
# 16. How many woman that were less than 18 actually died? Call the variable `dead_wo`

# %%
dead_wo=minor_wo[minor_wo["survived"]==True]
dead_wo
# Out:
#       pclass  survived                                       name     sex  \
# 1          1         1             Allison, Master. Hudson Trevor    male
# 54         1         1        Carter, Master. William Thornton II    male
# 55         1         1                  Carter, Miss. Lucile Polk  female
# 92         1         1  Dick, Mrs. Albert Adrian (Vera Gillespie)  female
# 94         1         1                  Dodge, Master. Washington    male
# ...      ...       ...                                        ...     ...
# 1240       3         1            Thomas, Master. Assad Alexander    male
# 1244       3         1  Thomas, Mrs. Alexander (Thamine "Thelma")  female
# 1256       3         1             Touma, Master. Georges Youssef    male
# 1257       3         1                 Touma, Miss. Maria Youssef  female
# 1300       3         1    Yasbeck, Mrs. Antoni (Selini Alexander)  female
#
#         age  sibsp  parch  ticket      fare    cabin embarked boat  body  \
# ...

# %%
dead_wo["survived"].value_counts()
# Out:
# 1    81
# Name: survived, dtype: int64

# %% [markdown]
# 17. Drop rows with *Nan* in `titanic` with `how='any'` and print the shape

# %%
titanic_4=titanic.dropna(how='any')
titanic_4
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
titanic_4.shape
# Out:
# (0, 14)

# %% [markdown]
# 18. Drop rows with *Nan* in `titanic` with `how='all'` and print the shape

# %%
titanic_5=titanic.dropna(how='all')
titanic_5
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.shape
# Out:
# (1309, 14)

# %% [markdown]
# Check in [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html) why the shapes are different.

# %% [markdown]
# 19. Drop columns in `titanic` with more than 1000 missing values and print the columns remaining

# %%
titanic.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
titanic_6=titanic.drop(["cabin","body"],axis=1)
titanic_6
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare embarked boat  \
# ...

# %% [markdown]
# 20. Calculate the ratio of missing values at the `boat` column.

# %%
ratio_nan = ((titanic.isnull().sum() / len(titanic))*100).sort_values(ascending = False)
print(ratio_nan)
# Out:
# body         90.756303
# cabin        77.463713
# boat         62.872422
# home.dest    43.086325
# age          20.091673
# embarked      0.152788
# fare          0.076394
# ticket        0.000000
# parch         0.000000
# sibsp         0.000000
# sex           0.000000
# name          0.000000
# survived      0.000000
# pclass        0.000000
# dtype: float64

# %% [markdown]
# 21.  Group `titanic` by `'pclass'` and aggregate by the columns `age` & `fare`, by `max` and `median` --> `by_class`

# %%
titanic.groupby("pclass").age.agg(['median','max'])
# Out:
#         median   max
# pclass
# 1         39.0  80.0
# 2         29.0  70.0
# 3         24.0  74.0

# %%
titanic.groupby("pclass").fare.agg(['median','max'])
# Out:
#          median       max
# pclass
# 1       60.0000  512.3292
# 2       15.0458   73.5000
# 3        8.0500   69.5500

# %% [markdown]
# 22. Print the maximum age in each class from `by_class`

# %%
titanic.groupby("pclass").age.max()
# Out:
# pclass
# 1    80.0
# 2    70.0
# 3    74.0
# Name: age, dtype: float64

# %% [markdown]
# 23. Print the median fare in each class from `by_class`

# %%
titanic.groupby("pclass").fare.median()
# Out:
# pclass
# 1    60.0000
# 2    15.0458
# 3     8.0500
# Name: fare, dtype: float64

# %% [markdown]
# 24. Using [`.pivot_table()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html) to count how many women or men survived by class, call it `counted`.
#
# Don't panic and read the documentation!

# %%
titanic_7 = pd.pivot_table(titanic, values='survived', index=['pclass'],columns=['sex'], aggfunc=np.sum)
titanic_7
# Out:
# sex     female  male
# pclass
# 1          139    61
# 2           94    25
# 3          106    75

# %% [markdown]
# 25. Add a new column with the sum of survived men and women, call it `counted['total']`

# %%
 titanic_7.loc[:,"counted[total]"] =titanic_7.sum(axis=1)
 titanic_7
# Out:
# sex     female  male  counted[total]
# pclass
# 1          139    61             200
# 2           94    25             119
# 3          106    75             181

# %% [markdown]
# 26. Sort `counted` by the `'total'` column. In which class the people survived the more?

# %%
titanic_8=titanic_7.sort_values(["counted[total]"],ascending=False)
titanic_8
# Out:
# sex     female  male  counted[total]
# pclass
# 1          139    61             200
# 3          106    75             181
# 2           94    25             119

# %% [markdown]
# 27. Please, show only the rows using a mask with the following conditions:
#     - They are woman
#     - From third class
#     - Younger than 30
#     - They survived
#
#     ¿How many rows fulfill the condition?

# %%
df1= titanic[(titanic.sex== "female")]

# %%
df2=df1[(df1.pclass==3)]

# %%
df3=df2[(df2.age<30)]
df3
# Out:
#       pclass  survived                                             name  \
# 604        3         1                      Abelseth, Miss. Karen Marie
# 607        3         1        Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 612        3         1                       Aks, Mrs. Sam (Leah Rosen)
# 621        3         1  Andersen-Jensen, Miss. Carla Christine Nielsine
# 623        3         0               Andersson, Miss. Ebba Iris Alfrida
# ...      ...       ...                                              ...
# 1265       3         0                        Van Impe, Miss. Catharina
# 1273       3         0               Vander Planke, Miss. Augusta Maria
# 1279       3         0             Vestrom, Miss. Hulda Amanda Adolfina
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
#
#          sex   age  sibsp  parch  ticket     fare cabin embarked boat   body  \
# ...

# %%
df4=df3[(df3.survived==1)]
df4.shape[0]
# Out:
# 57

# %% [markdown]
# 28. Now, show only the rows using `.loc` with the following conditions:
#     - They are man
#     - From first class
#     - Older than 50
#     - They died
#
#     ¿How many rows fulfill the condition?

# %%
is_male = titanic.loc[:,'sex'] == 'male'
d1 = titanic.loc [is_male]

# %%
primera= titanic.loc[:,'pclass'] ==1
d2 = d1.loc [primera]

# %%
older= titanic.loc[:,'age']>50
d3 = d2.loc [older]

# %%
fallecidos= titanic.loc[:,'survived']==0
d4 = d3.loc [fallecidos]
d4
# Out:
#      pclass  survived                            name   sex   age  sibsp  \
# 9         1         0         Artagaveytia, Mr. Ramon  male  71.0      0
# 81        1         0    Crosby, Capt. Edward Gifford  male  70.0      1
# 115       1         0               Fortune, Mr. Mark  male  64.0      1
# 135       1         0       Goldschmidt, Mr. George B  male  71.0      0
# 154       1         0      Hays, Mr. Charles Melville  male  55.0      1
# 158       1         0     Hipkins, Mr. William Edward  male  55.0      0
# 174       1         0         Kent, Mr. Edward Austin  male  58.0      0
# 201       1         0         McCarthy, Mr. Timothy J  male  54.0      0
# 205       1         0       Millet, Mr. Francis Davis  male  65.0      0
# 210       1         0      Molson, Mr. Harry Markland  male  55.0      0
# 215       1         0      Newell, Mr. Arthur Webster  male  58.0      0
# 217       1         0    Nicholson, Mr. Arthur Ernest  male  64.0      0
# ...

# %%
d4.shape[0]
# Out:
# 29

# %% [markdown]
# 29. Print the uniques values at the column `'name'`

# %%
titanic["name"].unique().tolist()
# Out:
# cis',
#  'Caldwell, Mrs. Albert Francis (Sylvia Mae Harbaugh)',
#  'Cameron, Miss. Clear Annie',
#  'Campbell, Mr. William',
#  'Carbines, Mr. William',
#  'Carter, Mrs. Ernest Courtenay (Lilian Hughes)',
#  'Carter, Rev. Ernest Courtenay',
#  'Chapman, Mr. Charles Henry',
#  'Chapman, Mr. John Henry',
#  'Chapman, Mrs. John Henry (Sara Elizabeth Lawry)',
#  'Christy, Miss. Julie Rachel',
#  'Christy, Mrs. (Alice Frances)',
#  'Clarke, Mr. Charles Valentine',
#  'Clarke, Mrs. Charles V (Ada Maria Winfield)',
#  'Coleridge, Mr. Reginald Charles',
#  'Collander, Mr. Erik Gustaf',
#  'Collett, Mr. Sidney C Stuart',
#  'Collyer, Miss. Marjorie "Lottie"',
#  'Collyer, Mr. Harvey',
#  'Collyer, Mrs. Harvey (Charlotte Annie Tate)',
#  'Cook, Mrs. (Selena Rogers)',
#  'Corbett, Mrs. Walter H (Irene Colvin)',
#  'Corey, Mrs. Percy C (Mary Phyllis Elizabeth Miller)',
#  'Cotterill, Mr. Henry "Harry"',
#  'Cunningham, Mr. Alfred Fleming',
#  'Davies, Master. John Morgan Jr',
# ...

# %% [markdown]
# 30. Find if was there any `name` repeated at the Titanic?
#
# Hint: There were two people with the same name, who?

# %%
titanic["name"].value_counts()
# Out:
# Kelly, Mr. James                     2
# Connolly, Miss. Kate                 2
# Andrews, Miss. Kornelia Theodosia    1
# Dooley, Mr. Patrick                  1
# Coelho, Mr. Domingos Fernandeo       1
#                                     ..
# Minkoff, Mr. Lazar                   1
# Nicholson, Mr. Arthur Ernest         1
# Jansson, Mr. Carl Olof               1
# Asplund, Master. Filip Oscar         1
# Givard, Mr. Hans Kristensen          1
# Name: name, Length: 1307, dtype: int64

# %% [markdown]
# 31. Using `matplotlib` find the appropriate visualization to show the distribution of the column `'age'`

# %%
titanic['age'].hist(bins=20)

# %%
titanic['age'].plot(kind='hist', bins=20)

# %%
edad_hombres = titanic.age[titanic.sex == 'male']
edad_mujeres = titanic.age[titanic.sex == 'female']

# %%
edad_hombres.hist(bins = np.arange(0,80,5),label = 'Hombres', alpha = 0.5)
edad_mujeres.hist(bins = np.arange(0,80,5),label = 'Mujeres', alpha = 0.5)
plt.title('Distribución de edades separadas por género de los pasajeros del Titanic')
plt.xlabel('Edad')
plt.legend()
plt.show()

# %% [markdown]
# 32. Using `matplotlib` find the appropriate plot to visualize the column `'gender'`

# %%
alpha_color=0.5
titanic["sex"].value_counts().plot(kind="bar",color=["b","r"],alpha=alpha_color)

# %% [markdown]
# 32b. What if you also plot the column `'gender'` using the function [`countplot`](https://seaborn.pydata.org/generated/seaborn.countplot.html) from the library [`seaborn`](https://seaborn.pydata.org/)?
#
# Remember you have never used `seaborn` before, therefore you should install it before importing it.

# %%
import seaborn as sns

# %%
fig = plt.figure(figsize=(10,6))
titanic.sex[titanic.survived == 1].value_counts(normalize = True).plot(kind="barh", alpha=0.5)
plt.title("sobrevivientes - Male VS female")
plt.show()

# %%
sns.countplot(x='sex', hue='survived', data=titanic)
plt.title('Supervivencia desagregada por genero')
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
#colors ``
titanic.pclass[titanic.survived == 1].value_counts(normalize = True).plot(kind="barh", alpha=0.5)
plt.title("Sobrevivientes por clase de ticket")
plt.show()

# %% [markdown]
# 33. Using the function [`catplot`](https://seaborn.pydata.org/generated/seaborn.catplot.html) from the library `seaborn`, find out if the hypothesis _"Women are more likely to survive shipwrecks"_ is true or not.
#
# You should get something like this:

# %%
g = sns.catplot(x="sex", y="survived",data=titanic, saturation=.5,
                kind="bar", ci=None, aspect=1)
(g.set_axis_labels("sex", "Survival Rate")
  .set_xticklabels(["Female", "Male"])
  .set_titles("{col_name} {col_var}")
  .set(ylim=(0, 1))
  .despine(left=True))

# %% [markdown]
# ![catplot](catplotgen.png)

# %% [markdown]
# 34. Using [`kdeplot`]("https://seaborn.pydata.org/generated/seaborn.kdeplot.html") from `seaborn` represent those who not survived distributed by age.
#
# Hint: First you should "filter" the `titanic` dataset where the column "survived" is 0, indexing the column `"age"` only.
#
# Arguments you should pass to the function:
#
#     - color = "red"
#     - label = "Not Survived"
#     - shade = True
#
# You should get something like this:

# %%
supervivientes= titanic.loc[:,'survived']==0
d5 = titanic.loc [supervivientes]
d5
# Out:
#       pclass  survived                                             name  \
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 7          1         0                           Andrews, Mr. Thomas Jr
# 9          1         0                          Artagaveytia, Mr. Ramon
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex   age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %%
d5.loc[:,["survived","age"]]
# Out:
#       survived   age
# 2            0   2.0
# 3            0  30.0
# 4            0  25.0
# 7            0  39.0
# 9            0  71.0
# ...        ...   ...
# 1304         0  14.5
# 1305         0   NaN
# 1306         0  26.5
# 1307         0  27.0
# 1308         0  29.0
#
# [809 rows x 2 columns]

# %%
sns.kdeplot(d5["age"], shade="True")
plt.xlabel("no supervivientes")
plt.show()

# %% [markdown]
# ![kdeplot](kdeplotsur.png)

# %%
#your code
