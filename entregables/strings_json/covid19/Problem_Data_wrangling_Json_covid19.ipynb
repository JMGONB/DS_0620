# %% [markdown]
# ## Working on Jsons

# %%
import requests
import json
import pandas as pd

# %%
r = requests.get(url='https://covid19tracking.narrativa.com/feed_en.json')
json_readed = json.loads(r.text)
json_readed
# Out:
# p_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/06/07&gen_time=13%3A41&client=default_web&region=world',
#     '_id': 'f26f5ce5f7307c5189a65f2d8689fdf6',
#     'id': '2020-6-7-13_01-COVID-world-en_generic_COVID_EN_GENERIC'},
#    {'date': '2020-06-07T12:14:23+02:00',
#     'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=7%20de%20junio%20del%202020&region=spain&aspect_ratio=square&client=default',
#      'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=7%20de%20junio%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#      'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#       'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#       'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#       'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#       'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#       'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#       'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#       'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#       'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#       'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#       'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#       'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#       'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#       'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#       'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#       'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#       'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#      'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C856%2C685&actives_num=3%2C370%2C761&recovered_num=3%2C095%2C634&deaths_num=390%2C290&date=7%20de%20junio%20del%202020&region=world&aspect_ratio=square&client=default',
#      'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C856%2C685&deaths_num=390%2C290&date=7%20de%20junio%20del%202020&top_countries=EE.UU.%20%281%2C920%2C061%29%2C%20Brasil%20%28672%2C846%29%2C%20Rusia%20%28467%2C073%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#      'composition_type': 'world',
#      'country_selected': None,
#      'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C856%2C685&actives_num=3%2C370%2C761&recovered_num=3%2C095%2C634&deaths_num=390%2C290&date=7%20de%20junio%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#      'state_selected': None},
#     'author': 'Narrativa',
#     '_rev': '1-4bfeb0cc1550ca689c2e964ae04289fb',
#     'language': 'en_generic',
#     'title': 'Coronavirus outbreak latest: <strong>2,042</strong> new deaths reported worldwide',
#     'content': '<p><small>Narrativa | Sunday, June 7, 2020 </small></p><p>There are now <strong>6,856,685</strong> <strong>people infected worldwide</strong>, with <strong>3,095,634</strong></strong> of these already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> tops the list with <strong>1,920,061</strong> recorded cases, followed by <b> Brazil</b>, <b> Russia</b>, and <b>The United Kingdom</b>, who have confirmed <strong>672,846, 467,073, and 286,294</strong> cases respectively.</p><h4>Status in the world</h4><p><table width="100%"><thead><tr><th><strong>Currently Infected</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 1,309,410</td><td>1. The US: 1,920,061</td><td>1. Brazil: 27,075</td><td>1. The US: 109,802</td><td>1. Brazil: 904</td><td>1. The US: 500,849</strong></td><td>1. Brazil: 10,209</strong></td></tr><tr><td>2. Brazil: 359,767</td><td>2. Brazil: 672,846</td><td>2. Russia: 8,971</td><td>2. The United Kingdom: 40,548</td><td>2. Mexico: 341</td><td>2. Brazil: 277,149</strong></td><td>2. Russia: 5,337</strong></td></tr><tr><td>3. The United Kingdom: 244,516</td><td>3. Russia: 467,073</td><td>3. Pakistan: 4,960</td><td>3. Brazil: 35,930</td><td>3. Russia: 134</td><td>3. Russia: 226,272</strong></td><td>3. Mexico: 2,989</strong></td></tr></tbody></table></p><p>During the last 24 hours, there has been a <strong>0.88</strong>% increase with <strong>60,084</strong> new positive cases. <strong> Brazil</strong> has the most new cases so far with <strong>27,075</strong>, followed by <b> Russia</b> with <strong>8,971</strong>. <strong> Pakistan</strong> and <strong> Mexico</strong> are not far behind, with <strong>4,960</strong> and <strong>3,593</strong> new cases respectively.</p><p> </p><p>Since the coronavirus outbreak started, a total of<strong> 390,290 people</strong> have died worldwide. <strong>The US</strong> is the country with the highest count so far with <strong>109,802</strong> deaths, followed by <strong>The United Kingdom, Brazil, and Italy</strong> with <strong>40,548, 35,930, and 33,846</strong> deaths respectively.</p><p>The first news of this new strain of COVID-19 appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since then, the virus has spread across Asia and the world. As of the latest reports, cases in China have grown to <strong>5</strong> new cases since yesterday. Overall, <strong>122</strong> people are infected with COVID-19.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/situacionActual.htm" target="_blank">Ministerio de Sanidad</a>, <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">Johns Hopkins University</a>.</p>',
#     'picurl_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C856%2C685&actives_num=3%2C370%2C761&recovered_num=3%2C095%2C634&deaths_num=390%2C290&date=7%20de%20junio%20del%202020&top_paises1=EE.UU.%3A%201%2C920%2C061&top_paises2=Brasil%3A%20672%2C846&top_paises3=Rusia%3A%20467%2C073&client=default&region=world',
#     'picurl': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=7%20de%20junio%20del%202020&top_comunidades=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&client=default&region=spain',
#     'metatitle': '',
#     'subtitle': '',
#     'picurl_banner_web': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C856%2C685&actives_num=3%2C370%2C761&recovered_num=3%2C095%2C634&deaths_num=390%2C290&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=7%20de%20junio%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C920%2C061&top_paises2_num=672%2C846&top_paises3_num=467%2C073&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/06/07&gen_time=12%3A06&client=default_web&region=world',
#     '_id': 'f26f5ce5f7307c5189a65f2d866eb97a',
#     'id': '2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC'},
#    {'date': '2020-06-07T11:08:41+02:00',
#     'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=7%20de%20junio%20del%202020&region=spain&aspect_ratio=square&client=default',
#      'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=7%20de%20junio%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#      'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#       'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#       'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#       'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#       'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#       'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#       'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#       'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#       'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#       'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#       'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#       'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#       'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#       'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#       'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#       'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#       'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#      'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C853%2C091&actives_num=3%2C368%2C548&recovered_num=3%2C094%2C361&deaths_num=390%2C182&date=7%20de%20junio%20del%202020&region=world&aspect_ratio=square&client=default',
#      'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C853%2C091&deaths_num=390%2C182&date=7%20de%20junio%20del%202020&top_countries=EE.UU.%20%281%2C920%2C061%29%2C%20Brasil%20%28672%2C846%29%2C%20Rusia%20%28467%2C073%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#      'composition_type': 'world',
#      'country_selected': None,
#      'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C853%2C091&actives_num=3%2C368%2C548&recovered_num=3%2C094%2C361&deaths_num=390%2C182&date=7%20de%20junio%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#      'state_selected': None},
#     'author': 'Narrativa',
#     '_rev': '1-8b45b3928461609482aeeaec870e8bbe',
#     'language': 'en_generic',
#     'title': 'Coronavirus outbreak latest: <strong>1,934</strong> new deaths reported worldwide',
#     'content': '<p><small>Narrativa | Sunday, June 7, 2020 </small></p><p>The number of COVID-19 cases has now reached <strong>6,853,091</strong> <strong>people worldwide</strong>, with <strong>3,094,361</strong></strong> of these having already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> has the most cases with <strong>1,920,061</strong>, followed by <b> Brazil</b>, <b> Russia</b>, and <b>The United Kingdom</b>, who have confirmed <strong>672,846, 467,073, and 286,294</strong> cases respectively.</p><h4>COVID-19 status across most infected countries</h4><p><table width="100%"><thead><tr><th><strong>Active Cases</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 1,309,410</td><td>1. The US: 1,920,061</td><td>1. Brazil: 27,075</td><td>1. The US: 109,802</td><td>1. Brazil: 904</td><td>1. The US: 500,849</strong></td><td>1. Brazil: 10,209</strong></td></tr><tr><td>2. Brazil: 359,767</td><td>2. Brazil: 672,846</td><td>2. Russia: 8,971</td><td>2. The United Kingdom: 40,548</td><td>2. Mexico: 341</td><td>2. Brazil: 277,149</strong></td><td>2. Russia: 5,337</strong></td></tr><tr><td>3. The United Kingdom: 244,516</td><td>3. Russia: 467,073</td><td>3. Pakistan: 4,960</td><td>3. Brazil: 35,930</td><td>3. Russia: 134</td><td>3. Russia: 226,272</strong></td><td>3. Mexico: 2,989</strong></td></tr></tbody></table></p><p>In addition, the last 24 hours have seen <strong>56,490</strong> new cases reported in the last 24 hours, an increase of <strong>0.83</strong>% from the previous day. <strong> Brazil</strong> is the country with the most new cases, having now confirmed <strong>27,075</strong>, followed by <b> Russia</b> with <strong>8,971</strong>. <strong> Pakistan</strong> and <strong> Mexico</strong> are not far behind, with <strong>3,593</strong> and <strong>3,593</strong> new patients respectively.</p><p> </p><p>So far, <strong>the total number of deaths from coronavirus worldwide</strong> stands at <strong>390,182 people</strong>, including the <strong>1,934</strong> new deaths over last 24 hours. <strong>The US</strong> has registered the most victims so far with <strong>109,802</strong> deceased, followed by <strong>The United Kingdom, Brazil, and Italy</strong> with <strong>40,548, 35,930, and 33,846</strong> deaths respectively.</p><p>The first reports of this new strain of the virus appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since that date, the number of infections have multiplied across the continent and the globe. At the moment, cases in China have grown to <strong>5</strong> new cases since yesterday. Overall, <strong>124</strong> people are infected with the virus.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/situacionActual.htm" target="_blank">Ministerio de Sanidad</a>, <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">Johns Hopkins University</a>.</p>',
#     'picurl_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C853%2C091&actives_num=3%2C368%2C548&recovered_num=3%2C094%2C361&deaths_num=390%2C182&date=7%20de%20junio%20del%202020&top_paises1=EE.UU.%3A%201%2C920%2C061&top_paises2=Brasil%3A%20672%2C846&top_paises3=Rusia%3A%20467%2C073&client=default&region=world',
#     'picurl': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=7%20de%20junio%20del%202020&top_comunidades=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&client=default&region=spain',
#     'metatitle': '',
#     'subtitle': '',
#     'picurl_banner_web': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C853%2C091&actives_num=3%2C368%2C548&recovered_num=3%2C094%2C361&deaths_num=390%2C182&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=7%20de%20junio%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C920%2C061&top_paises2_num=672%2C846&top_paises3_num=467%2C073&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/06/07&gen_time=11%3A04&client=default_web&region=world',
#     '_id': 'f26f5ce5f7307c5189a65f2d862e254c',
#     'id': '2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC'}]}}

# %%
print(json_readed)
# Out:
# vered_num=3%2C100%2C466&deaths_num=390%2C394&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=7%20de%20junio%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C920%2C061&top_paises2_num=672%2C846&top_paises3_num=467%2C073&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/06/07&gen_time=13%3A41&client=default_web&region=world', '_id': 'f26f5ce5f7307c5189a65f2d8689fdf6', 'id': '2020-6-7-13_01-COVID-world-en_generic_COVID_EN_GENERIC'}, {'date': '2020-06-07T12:14:23+02:00', 'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=7%20de%20junio%20del%202020&region=spain&aspect_ratio=square&client=default', 'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=7%20de%20junio%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true', 'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png', 'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png', 'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png', 'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png', 'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png', 'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png', 'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png', 'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png', 'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png', 'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png', 'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png', 'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png', 'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png', 'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png', 'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png', 'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png', 'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'}, 'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C856%2C685&actives_num=3%2C370%2C761&recovered_num=3%2C095%2C634&deaths_num=390%2C290&date=7%20de%20jun ...

# %% [markdown]
# Save json in a local file called "data.json"

# %%
with open('data.json', 'w+') as outfile:
    json.dump(json_readed, outfile)

# %%
with open('data.json') as f:
    line = f.readline()
    if line:
        print(line)
        line = f.readline()
print(line)
# Out:
# =233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=7%20de%20junio%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C920%2C061&top_paises2_num=672%2C846&top_paises3_num=467%2C073&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/06/07&gen_time=13%3A41&client=default_web&region=world", "_id": "f26f5ce5f7307c5189a65f2d8689fdf6", "id": "2020-6-7-13_01-COVID-world-en_generic_COVID_EN_GENERIC"}, {"date": "2020-06-07T12:14:23+02:00", "metadata": {"picurl_square_spain": "https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=7%20de%20junio%20del%202020&region=spain&aspect_ratio=square&client=default", "picurl_square_spain_extended": "https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=7%20de%20junio%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true", "graphs": {"graph_picurl_china": "https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png", "graph_picurl_us": "https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png", "graph_picurl_deaths_evolution": "https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png", "graph_picurl_world": "https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png", "graph_picurl_china_confirmed": "https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png", "graph_picurl_us_confirmed": "https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png", "graph_picurl_spain_deaths": "https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png", "graph_picurl_us_recovered": "https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png", "graph_picurl_deaths_log_evolution": "https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png", "graph_picurl_italy": "https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png", "graph_picurl_italy_recovered": "https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png", "graph_picurl_us_deaths": "https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png", "graph_picurl_italy_deaths": "https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png", "graph_picurl_china_deaths": "https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png", "graph_picurl_italy_confirmed": "https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png", "graph_picurl_spain_confirmed": "https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png", "graph_picurl_china_recovered": "https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png"}, "picurl_square_world": "https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C856%2C685&actives_num=3%2C370%2C761&recovered_num=3%2C095%2C634&deaths_num=390%2C290&date=7%20de%20junio%20del%202020&region=world&aspect_ratio=square&client=default", ...

# %% [markdown]
# Save with indent

# %%
with open('data_indented.json', 'w+') as outfile:
    json.dump(json_readed, outfile, indent=4)

# %% [markdown]
# Read local json

# %%
with open('data_indented.json', 'r+') as outfile:
    json_readed = json.load(outfile)
json_readed
# Out:
# p_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/06/07&gen_time=13%3A41&client=default_web&region=world',
#     '_id': 'f26f5ce5f7307c5189a65f2d8689fdf6',
#     'id': '2020-6-7-13_01-COVID-world-en_generic_COVID_EN_GENERIC'},
#    {'date': '2020-06-07T12:14:23+02:00',
#     'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=7%20de%20junio%20del%202020&region=spain&aspect_ratio=square&client=default',
#      'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=7%20de%20junio%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#      'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#       'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#       'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#       'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#       'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#       'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#       'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#       'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#       'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#       'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#       'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#       'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#       'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#       'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#       'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#       'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#       'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#      'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C856%2C685&actives_num=3%2C370%2C761&recovered_num=3%2C095%2C634&deaths_num=390%2C290&date=7%20de%20junio%20del%202020&region=world&aspect_ratio=square&client=default',
#      'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C856%2C685&deaths_num=390%2C290&date=7%20de%20junio%20del%202020&top_countries=EE.UU.%20%281%2C920%2C061%29%2C%20Brasil%20%28672%2C846%29%2C%20Rusia%20%28467%2C073%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#      'composition_type': 'world',
#      'country_selected': None,
#      'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C856%2C685&actives_num=3%2C370%2C761&recovered_num=3%2C095%2C634&deaths_num=390%2C290&date=7%20de%20junio%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#      'state_selected': None},
#     'author': 'Narrativa',
#     '_rev': '1-4bfeb0cc1550ca689c2e964ae04289fb',
#     'language': 'en_generic',
#     'title': 'Coronavirus outbreak latest: <strong>2,042</strong> new deaths reported worldwide',
#     'content': '<p><small>Narrativa | Sunday, June 7, 2020 </small></p><p>There are now <strong>6,856,685</strong> <strong>people infected worldwide</strong>, with <strong>3,095,634</strong></strong> of these already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> tops the list with <strong>1,920,061</strong> recorded cases, followed by <b> Brazil</b>, <b> Russia</b>, and <b>The United Kingdom</b>, who have confirmed <strong>672,846, 467,073, and 286,294</strong> cases respectively.</p><h4>Status in the world</h4><p><table width="100%"><thead><tr><th><strong>Currently Infected</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 1,309,410</td><td>1. The US: 1,920,061</td><td>1. Brazil: 27,075</td><td>1. The US: 109,802</td><td>1. Brazil: 904</td><td>1. The US: 500,849</strong></td><td>1. Brazil: 10,209</strong></td></tr><tr><td>2. Brazil: 359,767</td><td>2. Brazil: 672,846</td><td>2. Russia: 8,971</td><td>2. The United Kingdom: 40,548</td><td>2. Mexico: 341</td><td>2. Brazil: 277,149</strong></td><td>2. Russia: 5,337</strong></td></tr><tr><td>3. The United Kingdom: 244,516</td><td>3. Russia: 467,073</td><td>3. Pakistan: 4,960</td><td>3. Brazil: 35,930</td><td>3. Russia: 134</td><td>3. Russia: 226,272</strong></td><td>3. Mexico: 2,989</strong></td></tr></tbody></table></p><p>During the last 24 hours, there has been a <strong>0.88</strong>% increase with <strong>60,084</strong> new positive cases. <strong> Brazil</strong> has the most new cases so far with <strong>27,075</strong>, followed by <b> Russia</b> with <strong>8,971</strong>. <strong> Pakistan</strong> and <strong> Mexico</strong> are not far behind, with <strong>4,960</strong> and <strong>3,593</strong> new cases respectively.</p><p> </p><p>Since the coronavirus outbreak started, a total of<strong> 390,290 people</strong> have died worldwide. <strong>The US</strong> is the country with the highest count so far with <strong>109,802</strong> deaths, followed by <strong>The United Kingdom, Brazil, and Italy</strong> with <strong>40,548, 35,930, and 33,846</strong> deaths respectively.</p><p>The first news of this new strain of COVID-19 appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since then, the virus has spread across Asia and the world. As of the latest reports, cases in China have grown to <strong>5</strong> new cases since yesterday. Overall, <strong>122</strong> people are infected with COVID-19.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/situacionActual.htm" target="_blank">Ministerio de Sanidad</a>, <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">Johns Hopkins University</a>.</p>',
#     'picurl_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C856%2C685&actives_num=3%2C370%2C761&recovered_num=3%2C095%2C634&deaths_num=390%2C290&date=7%20de%20junio%20del%202020&top_paises1=EE.UU.%3A%201%2C920%2C061&top_paises2=Brasil%3A%20672%2C846&top_paises3=Rusia%3A%20467%2C073&client=default&region=world',
#     'picurl': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=7%20de%20junio%20del%202020&top_comunidades=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&client=default&region=spain',
#     'metatitle': '',
#     'subtitle': '',
#     'picurl_banner_web': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C856%2C685&actives_num=3%2C370%2C761&recovered_num=3%2C095%2C634&deaths_num=390%2C290&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=7%20de%20junio%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C920%2C061&top_paises2_num=672%2C846&top_paises3_num=467%2C073&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/06/07&gen_time=12%3A06&client=default_web&region=world',
#     '_id': 'f26f5ce5f7307c5189a65f2d866eb97a',
#     'id': '2020-6-7-12_01-COVID-world-en_generic_COVID_EN_GENERIC'},
#    {'date': '2020-06-07T11:08:41+02:00',
#     'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=7%20de%20junio%20del%202020&region=spain&aspect_ratio=square&client=default',
#      'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=7%20de%20junio%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#      'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#       'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#       'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#       'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#       'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#       'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#       'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#       'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#       'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#       'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#       'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#       'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#       'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#       'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#       'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#       'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#       'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#      'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C853%2C091&actives_num=3%2C368%2C548&recovered_num=3%2C094%2C361&deaths_num=390%2C182&date=7%20de%20junio%20del%202020&region=world&aspect_ratio=square&client=default',
#      'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C853%2C091&deaths_num=390%2C182&date=7%20de%20junio%20del%202020&top_countries=EE.UU.%20%281%2C920%2C061%29%2C%20Brasil%20%28672%2C846%29%2C%20Rusia%20%28467%2C073%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#      'composition_type': 'world',
#      'country_selected': None,
#      'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C853%2C091&actives_num=3%2C368%2C548&recovered_num=3%2C094%2C361&deaths_num=390%2C182&date=7%20de%20junio%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#      'state_selected': None},
#     'author': 'Narrativa',
#     '_rev': '1-8b45b3928461609482aeeaec870e8bbe',
#     'language': 'en_generic',
#     'title': 'Coronavirus outbreak latest: <strong>1,934</strong> new deaths reported worldwide',
#     'content': '<p><small>Narrativa | Sunday, June 7, 2020 </small></p><p>The number of COVID-19 cases has now reached <strong>6,853,091</strong> <strong>people worldwide</strong>, with <strong>3,094,361</strong></strong> of these having already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> has the most cases with <strong>1,920,061</strong>, followed by <b> Brazil</b>, <b> Russia</b>, and <b>The United Kingdom</b>, who have confirmed <strong>672,846, 467,073, and 286,294</strong> cases respectively.</p><h4>COVID-19 status across most infected countries</h4><p><table width="100%"><thead><tr><th><strong>Active Cases</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 1,309,410</td><td>1. The US: 1,920,061</td><td>1. Brazil: 27,075</td><td>1. The US: 109,802</td><td>1. Brazil: 904</td><td>1. The US: 500,849</strong></td><td>1. Brazil: 10,209</strong></td></tr><tr><td>2. Brazil: 359,767</td><td>2. Brazil: 672,846</td><td>2. Russia: 8,971</td><td>2. The United Kingdom: 40,548</td><td>2. Mexico: 341</td><td>2. Brazil: 277,149</strong></td><td>2. Russia: 5,337</strong></td></tr><tr><td>3. The United Kingdom: 244,516</td><td>3. Russia: 467,073</td><td>3. Pakistan: 4,960</td><td>3. Brazil: 35,930</td><td>3. Russia: 134</td><td>3. Russia: 226,272</strong></td><td>3. Mexico: 2,989</strong></td></tr></tbody></table></p><p>In addition, the last 24 hours have seen <strong>56,490</strong> new cases reported in the last 24 hours, an increase of <strong>0.83</strong>% from the previous day. <strong> Brazil</strong> is the country with the most new cases, having now confirmed <strong>27,075</strong>, followed by <b> Russia</b> with <strong>8,971</strong>. <strong> Pakistan</strong> and <strong> Mexico</strong> are not far behind, with <strong>3,593</strong> and <strong>3,593</strong> new patients respectively.</p><p> </p><p>So far, <strong>the total number of deaths from coronavirus worldwide</strong> stands at <strong>390,182 people</strong>, including the <strong>1,934</strong> new deaths over last 24 hours. <strong>The US</strong> has registered the most victims so far with <strong>109,802</strong> deceased, followed by <strong>The United Kingdom, Brazil, and Italy</strong> with <strong>40,548, 35,930, and 33,846</strong> deaths respectively.</p><p>The first reports of this new strain of the virus appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since that date, the number of infections have multiplied across the continent and the globe. At the moment, cases in China have grown to <strong>5</strong> new cases since yesterday. Overall, <strong>124</strong> people are infected with the virus.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/situacionActual.htm" target="_blank">Ministerio de Sanidad</a>, <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">Johns Hopkins University</a>.</p>',
#     'picurl_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C853%2C091&actives_num=3%2C368%2C548&recovered_num=3%2C094%2C361&deaths_num=390%2C182&date=7%20de%20junio%20del%202020&top_paises1=EE.UU.%3A%201%2C920%2C061&top_paises2=Brasil%3A%20672%2C846&top_paises3=Rusia%3A%20467%2C073&client=default&region=world',
#     'picurl': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=7%20de%20junio%20del%202020&top_comunidades=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&client=default&region=spain',
#     'metatitle': '',
#     'subtitle': '',
#     'picurl_banner_web': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=6%2C853%2C091&actives_num=3%2C368%2C548&recovered_num=3%2C094%2C361&deaths_num=390%2C182&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=7%20de%20junio%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C920%2C061&top_paises2_num=672%2C846&top_paises3_num=467%2C073&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/06/07&gen_time=11%3A04&client=default_web&region=world',
#     '_id': 'f26f5ce5f7307c5189a65f2d862e254c',
#     'id': '2020-6-7-11_01-COVID-world-en_generic_COVID_EN_GENERIC'}]}}

# %%
df_json = pd.read_json("data_indented.json")
df_json
# Out:
#                                                    data
# post  [{'date': '2020-07-29T09:02:37+02:00', 'metada...

# %% [markdown]
# ### Data Mining & Data Wrangling
# As you can see, there are jsons inside the original json. For that, we have to mining the json (data mining) to be able to use it correctly (data wrangling).
#
# How do you solve this issue? Research about this and try a solution.

# %%
# your code...
